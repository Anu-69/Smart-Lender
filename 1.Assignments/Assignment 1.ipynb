# %% [markdown]
# #task_1

# %%
import numpy as np

# %%
from numpy import random

# %%
x = random.randint(100,size=(4,4))

print(x)
# Out:
# [[ 8  2 37 91]
#  [61 58  2 93]
#  [83 28 72 29]
#  [36 32 23 32]]

# %%
import pandas as pd

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#     0   1   2   3
# 0   8   2  37  91
# 1  61  58   2  93
# 2  83  28  72  29
# 3  36  32  23  32

# %% [markdown]
# #task_2

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']

# %%
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               8               2              37              91
# 1              61              58               2              93
# 2              83              28              72              29
# 3              36              32              23              32

# %% [markdown]
# #task_3

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        47.000000       30.000000       33.500000       61.250000
# std         32.321304       22.920151       29.422214       35.537539
# min          8.000000        2.000000        2.000000       29.000000
# 25%         29.000000       21.500000       17.750000       31.250000
# 50%         48.500000       30.000000       30.000000       61.500000
# 75%         66.500000       38.500000       45.750000       91.500000
# max         83.000000       58.000000       72.000000       93.000000

# %% [markdown]
# #task_4

# %%
df.isnull().any()
# Out:
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      int64
#  1   Random value 2  4 non-null      int64
#  2   Random value 3  4 non-null      int64
#  3   Random value 4  4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %% [markdown]
# task_5

# %%
df.loc[:,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0               2              37
# 1              58               2
# 2              28              72
# 3              32              23

# %%
df.iloc[:,1:3]
# Out:
#    Random value 2  Random value 3
# 0               2              37
# 1              58               2
# 2              28              72
# 3              32              23
